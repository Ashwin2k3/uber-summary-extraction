# %%
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    # Open the PDF file
    doc = fitz.open(pdf_path)
    
    full_text = ""

    # Iterate through each page
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text = page.get_text()
        full_text += f"\n--- Page {page_num + 1} ---\n{text}"
    
    doc.close()
    return full_text

# Example usage:
pdf_file_path = "Uber July23 Tax Summary 2.pdf"  # Replace with your PDF path
text = extract_text_from_pdf(pdf_file_path)
print(text)
# Out:
# --- Page 1 ---
# HIMANSHU JANI
# 5 Barmera Avenue
# 5090 Hope Valley, Australia
# Australian Business Number (ABN): 47263282657
# Update tax information
# 01-31 July 2023
# Tax summary
# Thanks for driving on the Uber
# platform, HIMANSHU JANI!
# This tax summary is an official Uber document showing your
# gross earnings, fees, expenses and net pay. It also shows the
# total kilometres with riders, completed trips and tips.
# Transportation Income
# A$1,640.49
# Delivery Income
# A$0.00
# Other Payments
# A$37.00
# Total Payments
# A$1,677.49
# 601 km
# On Trip Mileage
# 92
# Trips
# A$16.00
# Tips
# Tax summary - 01-31 July 2023
# For more information on tax summaries and income tax return filing you can review these Definitions and FAQs.
# Page 1 of 5
#
# --- Page 2 ---
# HIMANSHU JANI
# 5 Barmera Avenue
# 5090 Hope Valley, Australia
# Australian Business Number (ABN): 47263282657
# Update tax information
# How your earnings were calculated
# 01-31 July 2023
# Transportation Income
# Gross transportation fare*
#
# A$1,471.89
# Split fare
#
# A$0.00
# Safe Rides Fee
#
# A$0.00
# Tolls Reimbursement
#
# A$0.00
# Miscellaneous
#
# A$0.00
# City fee
#
# A$91.00
# Airport fee
#
# A$0.00
# Booking fee
#
# A$77.60
# Total Transportation Income
#
# A$1,640.49
# *Gross fares are calculated as base + time + distance (this includes the Uber Service Fee)
# Tax summary - 01-31 July 2023
# For more information on tax summaries and income tax return filing you can review these Definitions and FAQs.
# Page 2 of 5
#
# --- Page 3 ---
# HIMANSHU JANI
# 5 Barmera Avenue
# 5090 Hope Valley, Australia
# Australian Business Number (ABN): 47263282657
# Update tax information
# How your earnings were calculated
# 01-31 July 2023
# Delivery Income
# Delivery Fee
#
# A$0.00
# Delivery Incentives
#
# A$0.00
# Tolls Reimbursement
#
# A$0.00
# Total Delivery Income
#
# A$0.00
# Other Payments
# Miscellaneous
#
# A$21.00
# Referral / Incentives
#
# A$0.00
# Tips
#
# A$16.00
# Total Other Payments
#
# A$37.00
# Tax summary - 01-31 July 2023
# For more information on tax summaries and income tax return filing you can review these Definitions and FAQs.
# Page 3 of 5
#
# --- Page 4 ---
# HIMANSHU JANI
# 5 Barmera Avenue
# 5090 Hope Valley, Australia
# Australian Business Number (ABN): 47263282657
# Update tax information
# Potential Tax Deductions
# 01-31 July 2023
# Deductions
# Some or all of these items may be tax deductible. Please consult a tax professional.
# Uber service fee (transportation leads)*
#
# A$396.88
# Other charges from Uber
#
# A$77.60
# Charges from 3rd parties (tolls/airports/government)
#
# A$91.00
# Total Potential Tax Deductions
#
# A$565.48
# On Trip Mileage
#
# 601 km
# *The Uber Service Fee is the fee drivers pay Uber for being able to operate on the platform. It varies from trip to trip. It's the difference
# between what a rider pays and what a driver earns on a trip, excluding tips, tolls, and certain fees, taxes, and surcharges.
# Tax summary - 01-31 July 2023
# For more information on tax summaries and income tax return filing you can review these Definitions and FAQs.
# Page 4 of 5
#
# --- Page 5 ---
# HIMANSHU JANI
# 5 Barmera Avenue
# 5090 Hope Valley, Australia
# Australian Business Number (ABN): 47263282657
# Update tax information
# Notes and disclaimers
# Updating your Tax Info
# You can manage your tax information via the Tax Settings section of the Uber Driver App. If you’ve changed
# your address or Tax ID and need to update them, please visit the Uber Driver App and open the Account menu,
# then tap on Tax Info followed by Tax Settings to get these items updated. If you are on a desktop computer,
# you can log in to the Driver Portal and follow this link to update your tax information
# https://drivers.uber.com/p3/tax-compliance/profile. Your tax summaries reflect the name, address and ABN
# tax ID you provide there.
# Tax-Deductible Items
# Many of the items listed in the tax summary may be tax deductible. For more information, we recommend that
# you seek guidance from a qualified tax site or service.
# This Is Not An Invoice
# This document is not an invoice or a regulatory tax form. The information in this tax summary does not reflect
# your personal tax situation and is for information purposes only. Nothing in this summary constitutes tax advice
# or an employment relationship between Uber and you, neither express nor implied. Please consult your local tax
# adviser or tax administration for your personal tax obligations.
# We are not tax advisers
# Uber is not a tax advisor. Please feel free to consult a qualified tax accountant to better understand your
# individual tax obligations. Every Partner is unique and so are their specific tax circumstances. As such, the
# information in this document may not cover your tax needs and it should not be relied upon to replace you
# seeking independent tax advice.
# Payout details
# This document is a Tax Summary. If you need details about your earnings,
# please visit the Payment Statements section of the Driver Portal.
# https://drivers.uber.com/p3/payments/statements
# Tax summary - 01-31 July 2023
# For more information on tax summaries and income tax return filing you can review these Definitions and FAQs.
# Page 5 of 5
